# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Imposta lo stile di Seaborn
sns.set(style="whitegrid")

# Carica i dati dal file CSV
data = pd.read_csv('Data/Channel_load/T1_C0.csv')

# Converti la colonna 'timestamp' in formato datetime
data['timestamp'] = pd.to_datetime(data['timestamp'])

# Imposta la colonna 'timestamp' come indice
data.set_index('timestamp', inplace=True)

# Crea il plot
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['minChannelLoad'], linestyle='-')
plt.title('Min Channel Load Over Time T1_C0')
plt.xlabel('Timestamp')
plt.ylabel('Min Channel Load')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Mostra il grafico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Imposta lo stile di Seaborn
sns.set(style="whitegrid")

# Carica i dati dal file CSV
data = pd.read_csv('Data/Channel_load/T1_C1.csv')

# Converti la colonna 'timestamp' in formato datetime
data['timestamp'] = pd.to_datetime(data['timestamp'])

# Imposta la colonna 'timestamp' come indice
data.set_index('timestamp', inplace=True)

# Crea il plot
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['minChannelLoad'], linestyle='-')
plt.title('Min Channel Load Over Time T1_C1')
plt.xlabel('Timestamp')
plt.ylabel('Min Channel Load')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Mostra il grafico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Imposta lo stile di Seaborn
sns.set(style="whitegrid")

# Carica i dati dal file CSV
data = pd.read_csv('Data/Channel_load/T1_C2.csv')

# Converti la colonna 'timestamp' in formato datetime
data['timestamp'] = pd.to_datetime(data['timestamp'])

# Imposta la colonna 'timestamp' come indice
data.set_index('timestamp', inplace=True)

# Crea il plot
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['minChannelLoad'], linestyle='-')
plt.title('Min Channel Load Over Time T1_C2')
plt.xlabel('Timestamp')
plt.ylabel('Min Channel Load')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Mostra il grafico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Imposta lo stile di Seaborn
sns.set(style="whitegrid")

# Carica i dati dal file CSV
data = pd.read_csv('Data/Channel_load/T2_C0.csv')

# Converti la colonna 'timestamp' in formato datetime
data['timestamp'] = pd.to_datetime(data['timestamp'])

# Imposta la colonna 'timestamp' come indice
data.set_index('timestamp', inplace=True)

# Crea il plot
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['minChannelLoad'], linestyle='-')
plt.title('Min Channel Load Over Time T2_C0')
plt.xlabel('Timestamp')
plt.ylabel('Min Channel Load')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Mostra il grafico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Imposta lo stile di Seaborn
sns.set(style="whitegrid")

# Carica i dati dal file CSV
data = pd.read_csv('Data/Channel_load/T2_C1.csv')

# Converti la colonna 'timestamp' in formato datetime
data['timestamp'] = pd.to_datetime(data['timestamp'])

# Imposta la colonna 'timestamp' come indice
data.set_index('timestamp', inplace=True)

# Crea il plot
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['minChannelLoad'], linestyle='-')
plt.title('Min Channel Load Over Time T2_C1')
plt.xlabel('Timestamp')
plt.ylabel('Min Channel Load')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Mostra il grafico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Imposta lo stile di Seaborn
sns.set(style="whitegrid")

# Carica i dati dal file CSV
data = pd.read_csv('Data/Channel_load/T2_C2.csv')

# Converti la colonna 'timestamp' in formato datetime
data['timestamp'] = pd.to_datetime(data['timestamp'])

# Imposta la colonna 'timestamp' come indice
data.set_index('timestamp', inplace=True)

# Crea il plot
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['minChannelLoad'], linestyle='-')
plt.title('Min Channel Load Over Time T2_C2')
plt.xlabel('Timestamp')
plt.ylabel('Min Channel Load')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Mostra il grafico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Imposta lo stile di Seaborn
sns.set(style="whitegrid")

# Carica i dati dal file CSV
data = pd.read_csv('Data/Channel_load/empty.csv')

# Converti la colonna 'timestamp' in formato datetime
data['timestamp'] = pd.to_datetime(data['timestamp'])

# Imposta la colonna 'timestamp' come indice
data.set_index('timestamp', inplace=True)

# Crea il plot
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['minChannelLoad'], linestyle='-')
plt.title('Min Channel Load Over Time NO TX')
plt.xlabel('Timestamp')
plt.ylabel('Min Channel Load')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Mostra il grafico
plt.show()
